# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],'max_features': ['sqrt','log2'],'n_estimators':[10,100,1000,2000,3000]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100, 1000, 2000, 3000]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(indep)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(dep,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 1000}: 0.9771743028532164

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.105391      0.007689         0.007607        0.004976
# 1        0.851477      0.012624         0.032515        0.005462
# 2        8.369721      0.221354         0.241415        0.014520
# 3       16.586999      0.144261         0.536565        0.033946
# 4       25.322055      0.165566         0.756970        0.029759
# 5        0.089891      0.004144         0.006040        0.000583
# 6        0.810049      0.020053         0.025890        0.010528
# 7        8.715983      0.212776         0.260689        0.010868
# 8       17.524576      0.162833         0.483400        0.017963
# 9       24.432030      0.639896         0.715475        0.022687
# 10       0.239156      0.007533         0.006028        0.007391
# 11       2.433026      0.040526         0.027343        0.005559
# 12      24.754827      0.852675         0.240354        0.012312
# 13      51.130549      1.262780         0.515292        0.068342
# 14      75.315489      1.535797         0.782675        0.125579
# 15       0.239379      0.018048         0.007044        0.006566
# 16       2.540016      0.053242         0.027231        0.001021
# 17      24.432307      0.286040         0.237434        0.032820
# 18      58.265197      2.381941         0.653042        0.062705
# 19      95.312868      2.585434         0.898593        0.188161
# 20       0.099704      0.003824         0.010601        0.006865
# 21       1.121484      0.101715         0.046998        0.010305
# 22      10.532260      0.299835         0.310759        0.018922
# 23      22.215147      0.871953         0.688747        0.204509
# 24      26.359742      1.198306         0.741548        0.060817
# 25       0.108098      0.029987         0.006475        0.003341
# 26       0.867062      0.070398         0.034475        0.022838
# 27       8.383310      0.227432         0.276155        0.042162
# 28      19.606015      1.075620         0.767366        0.177618
# 29      37.989700      3.942935         1.703096        0.481681
# 30       0.151251      0.015733         0.012420        0.002596
# 31       1.715454      0.289210         0.050657        0.010951
# 32      15.963945      1.673837         0.397989        0.039339
# 33      30.578546      1.400457         0.753392        0.086487
# 34      42.929198      2.121982         1.035399        0.077276
# 35       0.178751      0.024362         0.018875        0.007936
# 36       1.602378      0.191105         0.054077        0.019879
# 37      14.562313      1.369465         0.374510        0.050674
# 38      25.572419      0.826366         0.623266        0.036739
# 39      31.916561      3.189840         0.609609        0.145746
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               sqrt               1000
# 3    squared_error               sqrt               2000
# 4    squared_error               sqrt               3000
# 5    squared_error               log2                 10
# 6    squared_error               log2                100
# 7    squared_error               log2               1000
# 8    squared_error               log2               2000
# 9    squared_error               log2               3000
# 10  absolute_error               sqrt                 10
# 11  absolute_error               sqrt                100
# 12  absolute_error               sqrt               1000
# 13  absolute_error               sqrt               2000
# 14  absolute_error               sqrt               3000
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                100
# 17  absolute_error               log2               1000
# 18  absolute_error               log2               2000
# 19  absolute_error               log2               3000
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               sqrt               1000
# 23    friedman_mse               sqrt               2000
# 24    friedman_mse               sqrt               3000
# 25    friedman_mse               log2                 10
# 26    friedman_mse               log2                100
# 27    friedman_mse               log2               1000
# 28    friedman_mse               log2               2000
# 29    friedman_mse               log2               3000
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                100
# 32         poisson               sqrt               1000
# 33         poisson               sqrt               2000
# 34         poisson               sqrt               3000
# 35         poisson               log2                 10
# 36         poisson               log2                100
# 37         poisson               log2               1000
# 38         poisson               log2               2000
# 39         poisson               log2               3000
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.853758
# 1   {'criterion': 'squared_error', 'max_features':...           0.857653
# 2   {'criterion': 'squared_error', 'max_features':...           0.859316
# 3   {'criterion': 'squared_error', 'max_features':...           0.858890
# 4   {'criterion': 'squared_error', 'max_features':...           0.859904
# 5   {'criterion': 'squared_error', 'max_features':...           0.847617
# 6   {'criterion': 'squared_error', 'max_features':...           0.859097
# 7   {'criterion': 'squared_error', 'max_features':...           0.859540
# 8   {'criterion': 'squared_error', 'max_features':...           0.859584
# 9   {'criterion': 'squared_error', 'max_features':...           0.860255
# 10  {'criterion': 'absolute_error', 'max_features'...           0.826387
# 11  {'criterion': 'absolute_error', 'max_features'...           0.858965
# 12  {'criterion': 'absolute_error', 'max_features'...           0.857719
# 13  {'criterion': 'absolute_error', 'max_features'...           0.858705
# 14  {'criterion': 'absolute_error', 'max_features'...           0.858859
# 15  {'criterion': 'absolute_error', 'max_features'...           0.839817
# 16  {'criterion': 'absolute_error', 'max_features'...           0.856511
# 17  {'criterion': 'absolute_error', 'max_features'...           0.858579
# 18  {'criterion': 'absolute_error', 'max_features'...           0.858614
# 19  {'criterion': 'absolute_error', 'max_features'...           0.859458
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.826213
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.859230
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.860357
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.859126
# 24  {'criterion': 'friedman_mse', 'max_features': ...           0.859602
# 25  {'criterion': 'friedman_mse', 'max_features': ...           0.848344
# 26  {'criterion': 'friedman_mse', 'max_features': ...           0.855451
# 27  {'criterion': 'friedman_mse', 'max_features': ...           0.859072
# 28  {'criterion': 'friedman_mse', 'max_features': ...           0.860086
# 29  {'criterion': 'friedman_mse', 'max_features': ...           0.860189
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.838636
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857175
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859017
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859455
# 34  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859869
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.854335
# 36  {'criterion': 'poisson', 'max_features': 'log2...           0.860705
# 37  {'criterion': 'poisson', 'max_features': 'log2...           0.859998
# 38  {'criterion': 'poisson', 'max_features': 'log2...           0.859148
# 39  {'criterion': 'poisson', 'max_features': 'log2...           0.859490
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.765651           0.845004           0.818819
# 1            0.774922           0.862340           0.828814
# 2            0.780949           0.862489           0.830997
# 3            0.780537           0.862064           0.830041
# 4            0.780696           0.862020           0.830597
# 5            0.762057           0.847690           0.827067
# 6            0.783085           0.854089           0.829697
# 7            0.780952           0.862294           0.830349
# 8            0.781453           0.862551           0.830549
# 9            0.780985           0.862368           0.830304
# 10           0.762974           0.862262           0.819792
# 11           0.783209           0.851055           0.826144
# 12           0.782251           0.858380           0.829456
# 13           0.781234           0.858503           0.830075
# 14           0.782252           0.858489           0.829778
# 15           0.754697           0.849346           0.807649
# 16           0.783728           0.856488           0.826741
# 17           0.780404           0.859039           0.829718
# 18           0.782429           0.857966           0.829329
# 19           0.780874           0.857562           0.829817
# 20           0.761541           0.830731           0.812684
# 21           0.779376           0.863924           0.822768
# 22           0.780317           0.861712           0.830544
# 23           0.781106           0.862675           0.830058
# 24           0.780677           0.863016           0.830346
# 25           0.761030           0.828721           0.805886
# 26           0.781621           0.855303           0.829237
# 27           0.780072           0.863587           0.830644
# 28           0.781221           0.862283           0.831353
# 29           0.781328           0.862606           0.830534
# 30           0.749171           0.834732           0.806802
# 31           0.778046           0.859430           0.829188
# 32           0.781985           0.864213           0.830242
# 33           0.781931           0.862491           0.830724
# 34           0.781462           0.862352           0.829740
# 35           0.761819           0.837917           0.822474
# 36           0.779050           0.859613           0.829285
# 37           0.781944           0.862452           0.829787
# 38           0.780664           0.862882           0.829685
# 39           0.781155           0.862410           0.830091
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.821002         0.820847        0.030716               34
# 1            0.842157         0.833177        0.031442               29
# 2            0.842093         0.835169        0.029444                7
# 3            0.841855         0.834678        0.029463               21
# 4            0.841359         0.834915        0.029526               14
# 5            0.831451         0.823177        0.031678               33
# 6            0.841495         0.833493        0.027200               27
# 7            0.841004         0.834828        0.029414               18
# 8            0.841822         0.835192        0.029315                6
# 9            0.841204         0.835023        0.029546                8
# 10           0.827009         0.819685        0.032024               35
# 11           0.843331         0.832541        0.026952               31
# 12           0.844002         0.834362        0.028124               24
# 13           0.845031         0.834709        0.028739               20
# 14           0.845370         0.834949        0.028419               13
# 15           0.843706         0.819043        0.035294               37
# 16           0.839383         0.832570        0.026875               30
# 17           0.845566         0.834661        0.029167               22
# 18           0.845389         0.834745        0.028244               19
# 19           0.845465         0.834635        0.028888               23
# 20           0.824390         0.811112        0.025491               40
# 21           0.842425         0.833545        0.030698               26
# 22           0.841624         0.834911        0.029700               15
# 23           0.841489         0.834891        0.029390               17
# 24           0.841385         0.835005        0.029677               10
# 25           0.824019         0.813600        0.029555               38
# 26           0.839607         0.832244        0.027189               32
# 27           0.841635         0.835002        0.029923               11
# 28           0.841802         0.835349        0.029410                2
# 29           0.841428         0.835217        0.029456                5
# 30           0.828482         0.811564        0.033080               39
# 31           0.842423         0.833253        0.029685               28
# 32           0.841056         0.835303        0.029325                3
# 33           0.841744         0.835269        0.029098                4
# 34           0.841687         0.835022        0.029344                9
# 35           0.821633         0.819636        0.031283               36
# 36           0.840745         0.833880        0.029854               25
# 37           0.842581         0.835352        0.029249                1
# 38           0.842546         0.834985        0.029658               12
# 39           0.841388         0.834907        0.029378               16

# %%
import pickle
filename="finalized_grid_model_RF_withoutTrain.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:34
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
loaded_model=pickle.load(open("finalized_grid_model_RF_withoutTrain.sav",'rb'))
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[7061.92684668]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],'max_features': ['sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose=3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8698092434650162

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.339322      0.054182         0.043919        0.048004
# 1        3.656112      0.532005         0.149902        0.062628
# 2        0.323194      0.075446         0.034622        0.061715
# 3        3.703297      0.550578         0.160515        0.052324
# 4        1.077303      0.138412         0.051744        0.056051
# 5       10.230915      0.245688         0.152998        0.060939
# 6        1.162612      0.129565         0.006257        0.007663
# 7        9.392701      0.987285         0.120347        0.076472
# 8        0.441922      0.085629         0.010658        0.005906
# 9        3.783849      0.424710         0.151256        0.060459
# 10       0.358933      0.058112         0.047506        0.057920
# 11       3.836751      0.172486         0.188650        0.009971
# 12       0.474093      0.065402         0.011258        0.018139
# 13       4.157762      0.066244         0.147869        0.062729
# 14       0.389451      0.015664         0.003125        0.006250
# 15       3.101689      1.025168         0.116255        0.051273
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4   absolute_error               sqrt                 10
# 5   absolute_error               sqrt                100
# 6   absolute_error               log2                 10
# 7   absolute_error               log2                100
# 8     friedman_mse               sqrt                 10
# 9     friedman_mse               sqrt                100
# 10    friedman_mse               log2                 10
# 11    friedman_mse               log2                100
# 12         poisson               sqrt                 10
# 13         poisson               sqrt                100
# 14         poisson               log2                 10
# 15         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.775955
# 1   {'criterion': 'squared_error', 'max_features':...           0.802016
# 2   {'criterion': 'squared_error', 'max_features':...           0.762383
# 3   {'criterion': 'squared_error', 'max_features':...           0.815636
# 4   {'criterion': 'absolute_error', 'max_features'...           0.773752
# 5   {'criterion': 'absolute_error', 'max_features'...           0.795364
# 6   {'criterion': 'absolute_error', 'max_features'...           0.770246
# 7   {'criterion': 'absolute_error', 'max_features'...           0.804048
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.789614
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.803280
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.792675
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.803829
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.778431
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.808475
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.785140
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.802910
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.762049           0.825750           0.788996
# 1            0.770371           0.832904           0.837269
# 2            0.748778           0.822924           0.805530
# 3            0.767602           0.835457           0.830490
# 4            0.774686           0.845358           0.804089
# 5            0.772781           0.838184           0.833527
# 6            0.731466           0.828044           0.782815
# 7            0.775794           0.840532           0.825425
# 8            0.740604           0.811695           0.809989
# 9            0.773989           0.834051           0.832375
# 10           0.717669           0.815692           0.809990
# 11           0.767030           0.833728           0.834138
# 12           0.740241           0.791217           0.805307
# 13           0.765642           0.835420           0.824633
# 14           0.753634           0.802874           0.810610
# 15           0.768618           0.833155           0.829840
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.737655         0.778081        0.029283               12
# 1            0.758734         0.800259        0.031800                5
# 2            0.745943         0.777111        0.031297               13
# 3            0.761495         0.802136        0.031435                1
# 4            0.748012         0.789179        0.033230                9
# 5            0.762710         0.800513        0.030769                4
# 6            0.727039         0.767922        0.036993               15
# 7            0.764007         0.801961        0.028871                2
# 8            0.751799         0.780740        0.029465               10
# 9            0.760963         0.800932        0.029714                3
# 10           0.735015         0.774208        0.040187               14
# 11           0.757979         0.799341        0.032150                6
# 12           0.707863         0.764612        0.035691               16
# 13           0.757217         0.798277        0.031398                8
# 14           0.741226         0.778697        0.027117               11
# 15           0.760621         0.799029        0.030097                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:45
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[40548.0506239]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

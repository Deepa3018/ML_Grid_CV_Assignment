# %%
#Pandas is a Python library that provides high-level data structures and data analysis tools
import pandas as pd

# %%
# Reading the Dataset using read_csv
dataset = pd.read_csv('insurance_pre.csv')

# %%
#display dataset from 50_Startups.csv
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#As one of the input is a nominal value we use one hot encoding to make it into numbers and reduce the columns using drop opearation
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
#specifying input/output datasets
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#sklearn.model_selection is a popular machine learning library in Python. 
#This module provides various functionalities for splitting datasets 
from sklearn.model_selection import train_test_split
#This code splits the dataset into training and testing sets.
x_train,x_test,y_train,y_test=train_test_split(indep,dep)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
param_grid={"copy_X": [True, False],"fit_intercept": [True, False], "n_jobs": [None],"positive": [True, False]}
grid = GridSearchCV(LinearRegression(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None],
#                          'positive': [True, False]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(x_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': True}: 0.7569428013728057

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_copy_X  \
# 0       0.032423      0.045085         0.026778        0.042073         True
# 1       0.088585      0.052411         0.002702        0.005405         True
# 2       0.050823      0.056155         0.006132        0.007513         True
# 3       0.003128      0.006257         0.049548        0.057339         True
# 4       0.026210      0.050682         0.005428        0.006774        False
# 5       0.029617      0.047763         0.024721        0.042557        False
# 6       0.029382      0.043700         0.000771        0.001541        False
# 7       0.006392      0.007832         0.020456        0.033648        False
#
#   param_fit_intercept param_n_jobs param_positive  \
# 0                True         None           True
# 1                True         None          False
# 2               False         None           True
# 3               False         None          False
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:45
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[33585.18590596]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

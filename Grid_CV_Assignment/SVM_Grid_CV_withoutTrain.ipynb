# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[1,10,50],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 50], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.208206      0.005637         0.101165        0.010769       1
# 1     1783.267994    145.898861         0.031528        0.000388       1
# 2        0.134918      0.008956         0.029141        0.003837       1
# 3        0.150607      0.005653         0.025639        0.004326       1
# 4        0.190802      0.016003         0.094402        0.003281       1
# 5        0.154681      0.002621         0.030675        0.004918       1
# 6        0.206228      0.002840         0.051430        0.006519       1
# 7        0.148118      0.006625         0.024912        0.002982       1
# 8        0.208070      0.006838         0.094484        0.004567      10
# 9     3434.170506    565.181149         0.062265        0.029053      10
# 10       0.153685      0.006330         0.034673        0.006345      10
# 11       0.195815      0.009246         0.031252        0.000005      10
# 12       0.214404      0.006915         0.109142        0.001494      10
# 13       0.168340      0.008192         0.032896        0.007388      10
# 14       0.250802      0.000480         0.059853        0.006289      10
# 15       0.198479      0.006865         0.030513        0.001691      10
# 16       0.241040      0.006751         0.112566        0.004194      50
# 17    4154.677560    639.221052         0.017352        0.013204      50
# 18       0.166980      0.009795         0.030858        0.005233      50
# 19       0.316955      0.075456         0.030903        0.008173      50
# 20       0.215857      0.006268         0.109552        0.009890      50
# 21       0.180572      0.012089         0.029802        0.003869      50
# 22       0.248022      0.012554         0.059521        0.006384      50
# 23       0.308440      0.069190         0.028068        0.006229      50
#
#    param_gamma param_kernel                                            params  \
# 0         auto          rbf        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 1         auto         poly       {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 2         auto      sigmoid    {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 3         auto       linear     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 4        scale          rbf       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 5        scale         poly      {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 6        scale      sigmoid   {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 7        scale       linear    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 8         auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 9         auto         poly      {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 10        auto      sigmoid   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 11        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 12       scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 13       scale         poly     {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 14       scale      sigmoid  {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 15       scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 16        auto          rbf       {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
# 17        auto         poly      {'C': 50, 'gamma': 'auto', 'kernel': 'poly'}
# 18        auto      sigmoid   {'C': 50, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 19        auto       linear    {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# 20       scale          rbf      {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# 21       scale         poly     {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}
# 22       scale      sigmoid  {'C': 50, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 23       scale       linear   {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.115171          -0.113204          -0.081329
# 1            0.861782           0.776154           0.864823
# 2           -0.115328          -0.113567          -0.081608
# 3           -0.147592          -0.090685          -0.104805
# 4           -0.115390          -0.110235          -0.079858
# 5           -0.093867          -0.073490          -0.065017
# 6           -0.115186          -0.114434          -0.081691
# 7           -0.147592          -0.090685          -0.104805
# 8           -0.113791          -0.110741          -0.079156
# 9            0.858852           0.774048           0.862382
# 10          -0.115328          -0.113567          -0.081608
# 11          -0.018943           0.029886           0.022167
# 12          -0.110409          -0.097459          -0.074488
# 13          -0.125153          -0.081505          -0.111907
# 14          -0.116743          -0.119312          -0.085214
# 15          -0.018943           0.029886           0.022167
# 16          -0.107627          -0.105006          -0.077406
# 17           0.823598           0.743916           0.831529
# 18          -0.115328          -0.113567          -0.081608
# 19           0.435954           0.433943           0.439067
# 20          -0.149805          -0.104791          -0.111901
# 21          -0.134713          -0.084998          -0.131366
# 22          -0.128193          -0.136815          -0.099656
# 23           0.435954           0.433943           0.439067
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.105826          -0.107122        -0.104530        0.012126
# 1            0.792703           0.823719         0.823836        0.035673
# 2           -0.106067          -0.107195        -0.104753        0.012107
# 3           -0.123874          -0.202393        -0.133870        0.039226
# 4           -0.104068          -0.108358        -0.103582        0.012406
# 5           -0.092734          -0.112204        -0.087462        0.016613
# 6           -0.105744          -0.107748        -0.104961        0.012200
# 7           -0.123874          -0.202393        -0.133870        0.039226
# 8           -0.103389          -0.106488        -0.102713        0.012303
# 9            0.788049           0.823487         0.821363        0.035892
# 10          -0.106067          -0.107195        -0.104753        0.012107
# 11           0.003112          -0.066653        -0.006086        0.034672
# 12          -0.099597          -0.124428        -0.101276        0.016459
# 13          -0.131602          -0.179328        -0.125899        0.031794
# 14          -0.108210          -0.108716        -0.107639        0.012029
# 15           0.003112          -0.066653        -0.006086        0.034672
# 16          -0.099766          -0.105789        -0.099119        0.011166
# 17           0.774122           0.790738         0.792781        0.032222
# 18          -0.106067          -0.107195        -0.104753        0.012107
# 19           0.427335           0.391364         0.425533        0.017511
# 20          -0.132742          -0.192323        -0.138313        0.031310
# 21          -0.142516          -0.192095        -0.137138        0.034079
# 22          -0.118495          -0.118551        -0.120342        0.012390
# 23           0.427335           0.391364         0.425533        0.017511
#
#     rank_test_score
# 0                13
# 1                 1
# 2                14
# 3                21
# 4                12
# 5                 8
# 6                17
# 7                21
# 8                11
# 9                 2
# 10               14
# 11                6
# 12               10
# 13               20
# 14               18
# 15                6
# 16                9
# 17                3
# 18               14
# 19                4
# 20               24
# 21               23
# 22               19
# 23                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:45
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[51686.20123736]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

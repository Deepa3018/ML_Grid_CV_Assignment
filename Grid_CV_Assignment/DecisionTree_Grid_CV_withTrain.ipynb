# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features': ['sqrt','log2'],'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}: 0.7080143816477631

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.058900      0.055921         0.047844        0.059013
# 1        0.003124      0.006249         0.047075        0.045522
# 2        0.009381      0.007660         0.006231        0.007632
# 3        0.009383      0.007661         0.003126        0.006252
# 4        0.005428      0.006774         0.006250        0.007655
# 5        0.007253      0.007078         0.000000        0.000000
# 6        0.012505      0.006253         0.034505        0.039031
# 7        0.008053      0.007004         0.006854        0.007248
# 8        0.119602      0.064217         0.025652        0.051303
# 9        0.083980      0.052216         0.022902        0.043581
# 10       0.104083      0.060711         0.003265        0.006529
# 11       0.025348      0.007931         0.031760        0.055570
# 12       0.012378      0.006194         0.018831        0.037662
# 13       0.006255      0.007660         0.022117        0.029220
# 14       0.004228      0.006086         0.062790        0.045528
# 15       0.011379      0.006091         0.004228        0.006086
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.636758
# 1   {'criterion': 'squared_error', 'max_features':...           0.511431
# 2   {'criterion': 'squared_error', 'max_features':...           0.517987
# 3   {'criterion': 'squared_error', 'max_features':...           0.568450
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.692549
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.624289
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.598464
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.554187
# 8   {'criterion': 'absolute_error', 'max_features'...           0.693272
# 9   {'criterion': 'absolute_error', 'max_features'...           0.621025
# 10  {'criterion': 'absolute_error', 'max_features'...           0.417032
# 11  {'criterion': 'absolute_error', 'max_features'...           0.579927
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.584548
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.686676
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.631139
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.498081
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.566700           0.685864           0.653524
# 1            0.213183           0.597061           0.476921
# 2            0.587708           0.516302           0.606385
# 3            0.343748           0.559538           0.510278
# 4            0.506953           0.705672           0.607089
# 5            0.352054           0.742415           0.669628
# 6            0.673390           0.684178           0.580931
# 7            0.520725           0.702306           0.444289
# 8            0.477294           0.663769           0.567103
# 9            0.410312           0.460855           0.574176
# 10           0.549823           0.634103           0.491313
# 11           0.545849           0.647281           0.547812
# 12           0.567158           0.700148           0.542259
# 13           0.594104           0.633753           0.638549
# 14           0.614148           0.758878           0.720995
# 15           0.568639           0.583026           0.582697
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.659735         0.640516        0.040145                3
# 1            0.574636         0.474647        0.137626               16
# 2            0.672135         0.580103        0.058562                8
# 3            0.536984         0.503800        0.082518               15
# 4            0.645163         0.631485        0.071446                5
# 5            0.512019         0.580081        0.136348                9
# 6            0.674508         0.642294        0.043464                2
# 7            0.631869         0.570675        0.089232               11
# 8            0.495837         0.579455        0.086769               10
# 9            0.559952         0.525264        0.077625               13
# 10           0.639523         0.546359        0.085025               12
# 11           0.647591         0.593692        0.045520                7
# 12           0.619387         0.602700        0.054810                6
# 13           0.610311         0.632679        0.031432                4
# 14           0.692684         0.683569        0.054265                1
# 15           0.361798         0.518848        0.084582               14

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:45
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[42112.2356]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

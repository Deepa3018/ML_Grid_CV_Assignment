# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[5,10,50],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [5, 10, 50], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.072517      0.007572         0.039664        0.006971       5
# 1     3236.108219   1783.191831         0.033273        0.033863       5
# 2        0.049316      0.003624         0.008711        0.005304       5
# 3        0.059191      0.011208         0.010872        0.007941       5
# 4        0.065573      0.006799         0.037845        0.007747       5
# 5        0.048754      0.007406         0.014745        0.006045       5
# 6        0.070959      0.007066         0.022280        0.007509       5
# 7        0.063008      0.000688         0.012276        0.006153       5
# 8        0.073009      0.005763         0.031677        0.000596      10
# 9     3591.463475   1170.507941         0.072909        0.041171      10
# 10       0.147602      0.007566         0.091124        0.006279      10
# 11       0.244658      0.007816         0.014804        0.008641      10
# 12       0.241499      0.027058         0.171436        0.039553      10
# 13       0.159336      0.026031         0.077064        0.030857      10
# 14       0.271091      0.011602         0.106687        0.006311      10
# 15       0.236882      0.040821         0.026886        0.034127      10
# 16       0.259593      0.016501         0.161335        0.040867      50
# 17    4296.540073   1247.255956         0.017045        0.002318      50
# 18       0.149838      0.006278         0.077934        0.032090      50
# 19       0.328868      0.049164         0.047262        0.042334      50
# 20       0.255601      0.010141         0.123805        0.006468      50
# 21       0.185321      0.045228         0.062929        0.038296      50
# 22       0.282918      0.038082         0.082714        0.035319      50
# 23       0.286703      0.032277         0.077325        0.032472      50
#
#    param_gamma param_kernel                                            params  \
# 0         auto          rbf        {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 1         auto         poly       {'C': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 2         auto      sigmoid    {'C': 5, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 3         auto       linear     {'C': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 4        scale          rbf       {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 5        scale         poly      {'C': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 6        scale      sigmoid   {'C': 5, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 7        scale       linear    {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 8         auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 9         auto         poly      {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 10        auto      sigmoid   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 11        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 12       scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 13       scale         poly     {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 14       scale      sigmoid  {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 15       scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 16        auto          rbf       {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
# 17        auto         poly      {'C': 50, 'gamma': 'auto', 'kernel': 'poly'}
# 18        auto      sigmoid   {'C': 50, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 19        auto       linear    {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# 20       scale          rbf      {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# 21       scale         poly     {'C': 50, 'gamma': 'scale', 'kernel': 'poly'}
# 22       scale      sigmoid  {'C': 50, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 23       scale       linear   {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.053607          -0.023683          -0.160267
# 1            0.805834           0.804201           0.851125
# 2           -0.054214          -0.023636          -0.160084
# 3           -0.102535           0.061483          -0.206961
# 4           -0.048978          -0.011784          -0.162219
# 5           -0.089852           0.044039          -0.196177
# 6           -0.054651          -0.025403          -0.161298
# 7           -0.102535           0.061483          -0.206961
# 8           -0.052760          -0.022768          -0.160176
# 9            0.805977           0.801521           0.848548
# 10          -0.054214          -0.023636          -0.160084
# 11          -0.052374           0.104434          -0.156399
# 12          -0.048970          -0.000543          -0.168834
# 13          -0.114842           0.037445          -0.223563
# 14          -0.055108          -0.026452          -0.164324
# 15          -0.052374           0.104434          -0.156399
# 16          -0.047551          -0.016430          -0.158817
# 17           0.784442           0.783410           0.820737
# 18          -0.054214          -0.023636          -0.160084
# 19           0.290040           0.394579           0.188676
# 20          -0.095965           0.019299          -0.223245
# 21          -0.141362           0.036704          -0.240623
# 22          -0.056428          -0.036838          -0.170445
# 23           0.290040           0.394579           0.188676
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.122756          -0.140575        -0.100178        0.052484
# 1            0.794608           0.759970         0.803148        0.029146
# 2           -0.123121          -0.141318        -0.100475        0.052495
# 3           -0.153293          -0.121792        -0.104620        0.090257
# 4           -0.126710          -0.138731        -0.097684        0.057347
# 5           -0.169425          -0.139839        -0.110251        0.084831
# 6           -0.123314          -0.141136        -0.101161        0.052168
# 7           -0.153293          -0.121792        -0.104620        0.090257
# 8           -0.123452          -0.139782        -0.099788        0.052820
# 9            0.796576           0.754242         0.801373        0.029970
# 10          -0.123121          -0.141318        -0.100475        0.052495
# 11          -0.102809          -0.079150        -0.057260        0.087808
# 12          -0.131191          -0.138045        -0.097516        0.062647
# 13          -0.195052          -0.149975        -0.129197        0.091268
# 14          -0.124064          -0.140386        -0.102067        0.052442
# 15          -0.102809          -0.079150        -0.057260        0.087808
# 16          -0.123759          -0.135877        -0.096487        0.054743
# 17           0.756289           0.725797         0.774135        0.031683
# 18          -0.123121          -0.141318        -0.100475        0.052495
# 19           0.247539           0.224383         0.269043        0.070874
# 20          -0.182673          -0.158983        -0.128313        0.084550
# 21          -0.223223          -0.160204        -0.145742        0.098510
# 22          -0.134589          -0.144015        -0.108463        0.052204
# 23           0.247539           0.224383         0.269043        0.070874
#
#     rank_test_score
# 0                12
# 1                 1
# 2                13
# 3                18
# 4                10
# 5                21
# 6                16
# 7                18
# 8                11
# 9                 2
# 10               13
# 11                6
# 12                9
# 13               23
# 14               17
# 15                6
# 16                8
# 17                3
# 18               13
# 19                4
# 20               22
# 21               24
# 22               20
# 23                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:45
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[51929.92039142]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
